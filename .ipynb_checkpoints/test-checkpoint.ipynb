# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('noshowappointments-kagglev2-may-2016.csv')
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#       patientid  appointmentid gender          scheduledday  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          appointmentday  age      neighbourhood  scholarship  hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received no-show
# 0         0           0        0             0      No
# ...

# %%
df.dtypes
# Out:
# patientid         float64
# appointmentid       int64
# gender             object
# scheduledday       object
# appointmentday     object
# age                 int64
# neighbourhood      object
# scholarship         int64
# hipertension        int64
# diabetes            int64
# alcoholism          int64
# handcap             int64
# sms_received        int64
# no-show            object
# dtype: object

# %%
df['appointmentday'] = pd.to_datetime(df['appointmentday'])
df['scheduledday'] = pd.to_datetime(df['scheduledday'])

# %%
df.dtypes
# Out:
# patientid                     float64
# appointmentid                   int64
# gender                         object
# scheduledday      datetime64[ns, UTC]
# appointmentday    datetime64[ns, UTC]
# age                             int64
# neighbourhood                  object
# scholarship                     int64
# hipertension                    int64
# diabetes                        int64
# alcoholism                      int64
# handcap                         int64
# sms_received                    int64
# no-show                        object
# dtype: object

# %%
df.head()
# Out:
#       patientid  appointmentid gender              scheduledday  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
#
#              appointmentday  age      neighbourhood  scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    hipertension  diabetes  alcoholism  handcap  sms_received no-show
# 0             1         0           0        0             0      No
# ...

# %%
df.corr()
# Out:
#                patientid  appointmentid       age  scholarship  hipertension  \
# patientid       1.000000       0.004039 -0.004139    -0.002880     -0.006441
# appointmentid   0.004039       1.000000 -0.019126     0.022615      0.012752
# age            -0.004139      -0.019126  1.000000    -0.092457      0.504586
# scholarship    -0.002880       0.022615 -0.092457     1.000000     -0.019729
# hipertension   -0.006441       0.012752  0.504586    -0.019729      1.000000
# diabetes        0.001605       0.022628  0.292391    -0.024894      0.433086
# alcoholism      0.011011       0.032944  0.095811     0.035022      0.087971
# handcap        -0.007916       0.014106  0.078033    -0.008586      0.080083
# sms_received   -0.009749      -0.256618  0.012643     0.001194     -0.006267
#
#                diabetes  alcoholism   handcap  sms_received
# patientid      0.001605    0.011011 -0.007916     -0.009749
# appointmentid  0.022628    0.032944  0.014106     -0.256618
# ...

# %%
df.plot(kind = 'scatter', x = df.groupby())
# Out:
#       patientid  appointmentid gender          scheduledday  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          appointmentday  age      neighbourhood  scholarship  hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received no-show appointmentdate
# 0         0           0        0             0      No      2016-04-29
# ...

# %%
df.dtypes
# Out:
# patientid          float64
# appointmentid        int64
# gender              object
# scheduledday        object
# appointmentday      object
# age                  int64
# neighbourhood       object
# scholarship          int64
# hipertension         int64
# diabetes             int64
# alcoholism           int64
# handcap              int64
# sms_received         int64
# no-show             object
# appointmentdate     object
# dtype: object

# %%
df[df.handcap == 1]
# Out:
#            patientid  appointmentid gender          scheduledday  \
# 147     2.984854e+14        5639200      F  2016-04-29T08:48:03Z
# 189     6.652525e+14        5640552      F  2016-04-29T10:56:26Z
# 190     9.458118e+09        5640554      M  2016-04-29T10:56:40Z
# 199     6.431747e+13        5639969      M  2016-04-29T09:54:38Z
# 211     9.873742e+12        5631146      F  2016-04-27T18:03:02Z
# ...              ...            ...    ...                   ...
# 110202  7.452949e+11        5767693      F  2016-06-03T06:43:21Z
# 110421  5.915522e+13        5763871      F  2016-06-02T09:30:30Z
# 110436  5.935464e+13        5784368      M  2016-06-07T15:43:32Z
# 110439  5.915522e+13        5784366      F  2016-06-07T15:43:17Z
# 110455  7.214919e+14        5772215      M  2016-06-03T14:53:55Z
#
#               appointmentday  age   neighbourhood  scholarship  hipertension  \
# 147     2016-04-29T00:00:00Z   65   UNIVERSITÁRIO            0             1
# ...

# %%
df['scheduledday01'] =  pd.to_datetime(df['scheduledday'])

# %%
df.head()
# Out:
#       patientid  appointmentid gender          scheduledday  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          appointmentday  age      neighbourhood  scholarship  hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    diabetes  alcoholism  handcap  sms_received no-show  \
# 0         0           0        0             0      No
# ...

# %%
x = df['scheduledday01'].dt.date == df['appointmentday01'].dt.date
df[x]
# Out:
#            patientid  appointmentid gender          scheduledday  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110511  8.235996e+11        5786742      F  2016-06-08T08:50:20Z
# 110512  9.876246e+13        5786368      F  2016-06-08T08:20:01Z
# 110513  8.674778e+13        5785964      M  2016-06-08T07:52:55Z
# 110514  2.695685e+12        5786567      F  2016-06-08T08:35:31Z
# 110517  5.574942e+12        5780122      F  2016-06-07T07:38:34Z
#
#               appointmentday  age      neighbourhood  scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.sms_received.groupby(df['scheduledday01'].dt.year).hist()
# Out:
# scheduledday01
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: sms_received, dtype: object

# %%
df['scheduledday01'].dt.month
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 110522    5
# 110523    5
# 110524    4
# 110525    4
# 110526    4
# Name: scheduledday01, Length: 110527, dtype: int64

# %%
df1 = df.dropna()

# %%
df1.size
# Out:
# 1768432

# %%
df.size
# Out:
# 1768432

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   patientid         110527 non-null  float64
#  1   appointmentid     110527 non-null  int64
#  2   gender            110527 non-null  object
#  3   scheduledday      110527 non-null  object
#  4   appointmentday    110527 non-null  object
#  5   age               110527 non-null  int64
#  6   neighbourhood     110527 non-null  object
#  7   scholarship       110527 non-null  int64
#  8   hipertension      110527 non-null  int64
#  9   diabetes          110527 non-null  int64
#  10  alcoholism        110527 non-null  int64
#  11  handcap           110527 non-null  int64
#  12  sms_received      110527 non-null  int64
#  13  no-show           110527 non-null  object
#  14  appointmentday01  110527 non-null  datetime64[ns, UTC]
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   patientid         110527 non-null  float64
#  1   appointmentid     110527 non-null  int64
#  2   gender            110527 non-null  object
#  3   scheduledday      110527 non-null  object
#  4   appointmentday    110527 non-null  object
#  5   age               110527 non-null  int64
#  6   neighbourhood     110527 non-null  object
#  7   scholarship       110527 non-null  int64
#  8   hipertension      110527 non-null  int64
#  9   diabetes          110527 non-null  int64
#  10  alcoholism        110527 non-null  int64
#  11  handcap           110527 non-null  int64
#  12  sms_received      110527 non-null  int64
#  13  no-show           110527 non-null  object
#  14  appointmentday01  110527 non-null  datetime64[ns, UTC]
# ...

# %%
df.describe()
# Out:
#           patientid  appointmentid            age    scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         hipertension       diabetes     alcoholism        handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.age.mean()
# Out:
# 37.08887421173107

# %%
df.corr()
# Out:
#                patientid  appointmentid       age  scholarship  hipertension  \
# patientid       1.000000       0.004039 -0.004139    -0.002880     -0.006441
# appointmentid   0.004039       1.000000 -0.019126     0.022615      0.012752
# age            -0.004139      -0.019126  1.000000    -0.092457      0.504586
# scholarship    -0.002880       0.022615 -0.092457     1.000000     -0.019729
# hipertension   -0.006441       0.012752  0.504586    -0.019729      1.000000
# diabetes        0.001605       0.022628  0.292391    -0.024894      0.433086
# alcoholism      0.011011       0.032944  0.095811     0.035022      0.087971
# handcap        -0.007916       0.014106  0.078033    -0.008586      0.080083
# sms_received   -0.009749      -0.256618  0.012643     0.001194     -0.006267
#
#                diabetes  alcoholism   handcap  sms_received
# patientid      0.001605    0.011011 -0.007916     -0.009749
# appointmentid  0.022628    0.032944  0.014106     -0.256618
# ...
